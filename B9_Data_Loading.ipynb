# %% [markdown]
# # Data Loading/ Pandas
#
# > **Pandas** is a Python module.
# > Pandas helps read in *CSV/Excel/Text/JSON/HTML* data.
# > Pandas makes use of 2 different data structures.
# > - Series
# > - Data Frame

# %%
import pandas as pd

# %%
wholesale = pd.read_csv("G:/My Drive/Teaching/PG_Bridging/Python/Wholesale_customers_data.csv")

# %%
wholesale.head()
# Out:
#    Channel  Region  Fresh  Milk  Grocery  Frozen  Detergents_Paper  Delicassen
# 0        2       3  12669  9656     7561     214              2674        1338
# 1        2       3   7057  9810     9568    1762              3293        1776
# 2        2       3   6353  8808     7684    2405              3516        7844
# 3        1       3  13265  1196     4221    6404               507        1788
# 4        2       3  22615  5410     7198    3915              1777        5185

# %%
wholesale.tail()
# Out:
#      Channel  Region  Fresh   Milk  Grocery  Frozen  Detergents_Paper  \
# 435        1       3  29703  12051    16027   13135               182
# 436        1       3  39228   1431      764    4510                93
# 437        2       3  14531  15488    30243     437             14841
# 438        1       3  10290   1981     2232    1038               168
# 439        1       3   2787   1698     2510      65               477
#
#      Delicassen
# 435        2204
# 436        2346
# 437        1867
# 438        2125
# 439          52

# %%
wine0 = pd.read_csv("G:/My Drive/Teaching/PG_Bridging/Python/winequality-red.csv")

# %%
wine0.head()
# Out:
#   fixed acidity;"volatile acidity";"citric acid";"residual sugar";"chlorides";"free sulfur dioxide";"total sulfur dioxide";"density";"pH";"sulphates";"alcohol";"quality"
# 0   7.4;0.7;0;1.9;0.076;11;34;0.9978;3.51;0.56;9.4;5
# 1   7.8;0.88;0;2.6;0.098;25;67;0.9968;3.2;0.68;9.8;5
# 2  7.8;0.76;0.04;2.3;0.092;15;54;0.997;3.26;0.65;...
# 3  11.2;0.28;0.56;1.9;0.075;17;60;0.998;3.16;0.58...
# 4   7.4;0.7;0;1.9;0.076;11;34;0.9978;3.51;0.56;9.4;5

# %%
wine = pd.read_csv("G:/My Drive/Teaching/PG_Bridging/Python/winequality-red.csv",sep=';')

# %%
wine.head()
# Out:
#    fixed acidity  volatile acidity  citric acid  residual sugar  chlorides  \
# 0            7.4              0.70         0.00             1.9      0.076
# 1            7.8              0.88         0.00             2.6      0.098
# 2            7.8              0.76         0.04             2.3      0.092
# 3           11.2              0.28         0.56             1.9      0.075
# 4            7.4              0.70         0.00             1.9      0.076
#
#    free sulfur dioxide  total sulfur dioxide  density    pH  sulphates  \
# 0                 11.0                  34.0   0.9978  3.51       0.56
# 1                 25.0                  67.0   0.9968  3.20       0.68
# 2                 15.0                  54.0   0.9970  3.26       0.65
# 3                 17.0                  60.0   0.9980  3.16       0.58
# 4                 11.0                  34.0   0.9978  3.51       0.56
#
#    alcohol  quality
# 0      9.4        5
# 1      9.8        5
# 2      9.8        5
# ...

# %%
# %pwd
# Out:
# 'G:\\My Drive\\Teaching\\PG_Bridging\\Python'

# %%
boston = pd.read_csv("bostonTxt.txt",sep='\t')

# %%
boston.head()
# Out:
#      MV  INDUS   NOX     RM  TAX    PT  LSTAT
# 0  24.0   2.31  53.8  6.575  296  15.3   4.98
# 1  21.6   7.07  46.9  6.421  242  17.8   9.14
# 2  34.7   7.07  46.9  7.185  242  17.8   4.03
# 3  33.4   2.18  45.8  6.998  222  18.7   2.94
# 4  36.2   2.18  45.8  7.147  222  18.7   5.33

# %%
goyal = pd.read_excel(io='http://www.hec.unil.ch/agoyal/docs/PredictorData2018.xlsx', 
                      sheet_name='Monthly')

# %%
goyal.head()
# Out:
#    yyyymm  Index   D12  E12  b/m  tbl  AAA  BAA  lty  ntis     Rfree  infl  \
# 0  187101   4.44  0.26  0.4  NaN  NaN  NaN  NaN  NaN   NaN  0.004955   NaN
# 1  187102   4.50  0.26  0.4  NaN  NaN  NaN  NaN  NaN   NaN  0.004514   NaN
# 2  187103   4.61  0.26  0.4  NaN  NaN  NaN  NaN  NaN   NaN  0.004243   NaN
# 3  187104   4.74  0.26  0.4  NaN  NaN  NaN  NaN  NaN   NaN  0.004632   NaN
# 4  187105   4.86  0.26  0.4  NaN  NaN  NaN  NaN  NaN   NaN  0.003691   NaN
#
#    ltr  corpr  svar  csp  CRSP_SPvw  CRSP_SPvwx
# 0  NaN    NaN   NaN  NaN        NaN         NaN
# 1  NaN    NaN   NaN  NaN        NaN         NaN
# 2  NaN    NaN   NaN  NaN        NaN         NaN
# 3  NaN    NaN   NaN  NaN        NaN         NaN
# 4  NaN    NaN   NaN  NaN        NaN         NaN

# %%
goyal.columns
# Out:
# Index(['yyyymm', 'Index', 'D12', 'E12', 'b/m', 'tbl', 'AAA', 'BAA', 'lty',
#        'ntis', 'Rfree', 'infl', 'ltr', 'corpr', 'svar', 'csp', 'CRSP_SPvw',
#        'CRSP_SPvwx'],
#       dtype='object')

# %%
goyal.shape
# Out:
# (1776, 18)

# %%
goyal.size
# Out:
# 31968

# %%
boston1 = pd.ExcelFile("boston1.xls")

# %%
print(boston1.sheet_names)
# Out:
# ['Sheet1', 'Sheet2']

# %%
df1 = boston1.parse('Sheet1')

# %%
df1.head()
# Out:
#      MV  INDUS   NOX     RM  TAX    PT  LSTAT  Unnamed: 7  Unnamed: 8  \
# 0  24.0   2.31  53.8  6.575  296  15.3   4.98         NaN         NaN
# 1  21.6   7.07  46.9  6.421  242  17.8   9.14         NaN         NaN
# 2  34.7   7.07  46.9  7.185  242  17.8   4.03         NaN         NaN
# 3  33.4   2.18  45.8  6.998  222  18.7   2.94         NaN         NaN
# 4  36.2   2.18  45.8  7.147  222  18.7   5.33         NaN         NaN
#
#                          Unnamed: 9
# 0    Subset of Boston housing tract
# 1    data of Harrison and Rubinfeld
# 2    (1978).  Each case is one U.S.
# 3  Census tract in the Boston area.
# 4                               NaN

# %%
# https://codebeautify.org/jsonviewer
df2 = pd.read_json("skorea.json")

# %%
df2.head()
# Out:
#   Area ha (acre)                 Criteria Description  \
# 0      135 (330)      Cultural: (ii)(iii)
# 1                         Cultural: (iii)
# 2                 Cultural: (ii)(iii)(iv)
# 3  2,880 (7,100)      Cultural: (ii)(iii)
# 4                      Cultural: (iv)(vi)
#
#                                                Image  \
# 0                       /wiki/File:MuryeongsTomb.jpg
# 1  /wiki/File:Korea-Gwangju-Gochang_Dolmens_5350-...
# 2  /wiki/File:Juhamnu,_Changdeokgung_-_Seoul,_Kor...
# 3  /wiki/File:Korea-Gyeongju-Bunhwangsa-Lanterns-...
# 4         /wiki/File:Haeinsa_Temple_(6222053899).jpg
#
#                               Location  \
# 0      South Chungcheong, North Jeolla
# 1  Incheon, North Jeolla, South Jeolla
# 2                                Seoul
# 3                     North Gyeongsang
# 4                     South Gyeongsang
#
#                                                 Site  Year
# 0                              Baekje Historic Areas  2015
# ...

# %%
df2.shape
# Out:
# (12, 7)

# %%
web = pd.read_json('https://api.github.com/repos/pydata/pandas/issues?per_page=5')

# %%
web.head(3)
# Out:
#    assignee assignees author_association  \
# 0       NaN        []             MEMBER
# 1       NaN        []             MEMBER
# 2       NaN        []               NONE
#
#                                                 body closed_at  comments  \
# 0  lot more to be done here but split these up as...       NaT         1
# 1  Follow-up on https://github.com/pandas-dev/pan...       NaT         2
# 2  #### Code Sample, a copy-pastable example if p...       NaT         0
#
#                                         comments_url          created_at  \
# 0  https://api.github.com/repos/pandas-dev/pandas... 2019-08-09 08:56:09
# 1  https://api.github.com/repos/pandas-dev/pandas... 2019-08-09 07:53:50
# 2  https://api.github.com/repos/pandas-dev/pandas... 2019-08-09 07:35:38
#
#                                           events_url  \
# 0  https://api.github.com/repos/pandas-dev/pandas...
# 1  https://api.github.com/repos/pandas-dev/pandas...
# ...

# %%
uss = pd.read_html('https://simple.wikipedia.org/wiki/List_of_U.S._states')

# %%
type(uss)
# Out:
# list

# %%
u0=uss[0]

# %%
imdb = pd.read_html('https://www.imdb.com/chart/top')
print(type(imdb))
# Out:
# <class 'list'>

# %%
imdb[0]['Rank & Title'][:10]
# Out:
# 0                 1.  The Shawshank Redemption  (1994)
# 1                            2.  The Godfather  (1972)
# 2                   3.  The Godfather: Part II  (1974)
# 3                          4.  The Dark Knight  (2008)
# 4                             5.  12 Angry Men  (1957)
# 5                         6.  Schindler's List  (1993)
# 6    7.  The Lord of the Rings: The Return of the K...
# 7                             8.  Pulp Fiction  (1994)
# 8          9.  Il buono, il brutto, il cattivo  (1966)
# 9                              10.  Fight Club  (1999)
# Name: Rank & Title, dtype: object
